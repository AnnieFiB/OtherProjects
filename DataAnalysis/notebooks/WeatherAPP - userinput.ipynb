# %% [markdown]
# # Real-Time Weather Dashboard with OpenWeather API

# %% [markdown]
# The project builds a Weather Dashboard using the OpenWeather API to fetch and display real-time weather details for one or two specified locations. Users can compare key weather data such as temperature, humidity, wind speed, and air conditions for these locations, with an option to save the data to a CSV file for future analysis.
#
# The dashboard aims to enhance skills in API integration, interactive interface, and data visualization (via Matplotlib).

# %% [markdown]
# ## Load Required Libraries

# %%
import sys
import os
print(os.listdir("/kaggle/input/hlprfunct"))
# Get the absolute path of the 'scripts' directory
#scripts_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'scripts'))
#sys.path.append(scripts_path) # Add 'scripts' directory to sys.path
#import weather

import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.simplefilter(action="ignore", category=DeprecationWarning)
# Out:
# ['data_cleaning.py', 'mentalhealth.py', 'hrattrition.py', 'weatherk.py', 'stockforecast.py']

# %%
import importlib.util

file_path = "/kaggle/input/hlprfunct/weatherk.py"
spec = importlib.util.spec_from_file_location("weatherk", file_path)
if spec:
    weatherk = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(weatherk)
else:
    print("Failed to load the module.")

# %%
weatherk.main()
# Out:
# What would you like to do?
# 1. View Weather and Forecast for a City
# 2. Compare Weather and Forecast for 2 Cities
# Enter your choice (1/2):  1
# Enter the city name:  lagos
# Coordinates for 'lagos': Latitude = 6.4550575, Longitude = 3.3941795
#
# --- Weather Details ---
# +-------------------------+---------------------+
# | Attribute               | Value               |
# +=========================+=====================+
# | City                    | Lagos, NG           |
# +-------------------------+---------------------+
# | Current Time            | 2025-03-25 22:36:33 |
# +-------------------------+---------------------+
# | Temperature             | 29.13°C             |
# +-------------------------+---------------------+
# | Feels Like              | 36.04°C             |
# +-------------------------+---------------------+
# | Weather                 | few clouds          |
# +-------------------------+---------------------+
# | Pressure                | 1011 hPa            |
# +-------------------------+---------------------+
# | Humidity                | 84%                 |
# +-------------------------+---------------------+
# | Wind Speed              | 1.54 m/s            |
# +-------------------------+---------------------+
# | Rain (1h)               | 0 mm                |
# +-------------------------+---------------------+
# | Sunrise                 | 2025-03-25 06:48:06 |
# +-------------------------+---------------------+
# | Sunset                  | 2025-03-25 18:56:29 |
# +-------------------------+---------------------+
# | Air Quality Index (AQI) | Fair                |
# +-------------------------+---------------------+
# -----------------------
# --- Daily Forecast Summary ---
# +------------+------------+----------------+--------------+-----------------+---------+
# | Date       | Avg Temp   | Avg Humidity   | Total Rain   | Weather         | AQI     |
# +============+============+================+==============+=================+=========+
# | 2025-03-26 | 29.7°C     | 71.4%          | 7.0 mm       | light rain      | Good    |
# +------------+------------+----------------+--------------+-----------------+---------+
# | 2025-03-27 | 30.3°C     | 69.0%          | 0.8 mm       | overcast clouds | Fair    |
# +------------+------------+----------------+--------------+-----------------+---------+
# | 2025-03-28 | 30.5°C     | 67.0%          | 1.4 mm       | overcast clouds | Fair    |
# +------------+------------+----------------+--------------+-----------------+---------+
# | 2025-03-29 | 30.3°C     | 68.1%          | 0.9 mm       | light rain      | Good    |
# +------------+------------+----------------+--------------+-----------------+---------+
# | 2025-03-30 | 30.5°C     | 67.2%          | 2.8 mm       | light rain      | Unknown |
# +------------+------------+----------------+--------------+-----------------+---------+

# %% [markdown]
# <p align="center"><strong><em>STAY SAFE, STAY INFORMED, AND LET THE WEATHER BE YOUR GUIDE!</em></strong></p>
