# %% [markdown]
# # Real-Time Weather Dashboard with OpenWeather API

# %% [markdown]
# The project builds a Weather Dashboard using the OpenWeather API to fetch and display real-time weather details for one or two specified locations. Users can compare key weather data such as temperature, humidity, wind speed, and air conditions for these locations, with an option to save the data to a CSV file for future analysis.
#
# The dashboard aims to enhance skills in API integration, interactive interface, and data visualization (via Matplotlib).

# %% [markdown]
# ## Load Required Libraries

# %%
import sys
import os

# Get the absolute path of the 'scripts' directory
scripts_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'scripts'))
sys.path.append(scripts_path) # Add 'scripts' directory to sys.path
import weather

import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.simplefilter(action="ignore", category=DeprecationWarning)

# %%
weather.main()
# Out:
# 1. View city weather
# 2. Compare cities
# Choose option (1/2):  2
# First city:
# Enter city and country (e.g., 'London UK'):  london england
# Second city:
# Enter city and country (e.g., 'London UK'):  new york us
# === Current Weather Comparison ===
# +-------------+---------------------+---------------------+
# | Attribute   | City 1              | City 2              |
# +=============+=====================+=====================+
# | City        | London, GB          | New York, US        |
# +-------------+---------------------+---------------------+
# | Temperature | 17.03°C             | 14.76°C             |
# +-------------+---------------------+---------------------+
# | Feels Like  | 16.04°C             | 14.56°C             |
# +-------------+---------------------+---------------------+
# | Pressure    | 1028 hPa            | 1007 hPa            |
# +-------------+---------------------+---------------------+
# | Humidity    | 48%                 | 87%                 |
# +-------------+---------------------+---------------------+
# | Weather     | few clouds          | mist                |
# +-------------+---------------------+---------------------+
# | Wind Speed  | 3.6 m/s             | 4.12 m/s            |
# +-------------+---------------------+---------------------+
# | Rain (1h)   | 0 mm                | 0 mm                |
# +-------------+---------------------+---------------------+
# | Sunrise     | 06:37:47            | 06:40:41            |
# +-------------+---------------------+---------------------+
# | Sunset      | 19:31:11            | 19:19:12            |
# +-------------+---------------------+---------------------+
# | Updated     | 2025-03-31 15:35:00 | 2025-03-31 10:36:19 |
# +-------------+---------------------+---------------------+
# | AQI         | Fair (2)            | Fair (2)            |
# +-------------+---------------------+---------------------+
# === Combined Forecast Summary ===
# +------------+------------+----------------+--------------+----------------+------------+----------------+----------+
# | date       | Avg Temp   | Avg Humidity   | Total Rain   | Avg Pressure   | Avg Wind   | AQI            | City     |
# +============+============+================+==============+================+============+================+==========+
# | 2025-03-31 | 14.7°C     | 51.7%          | 0.0 mm       | 1028.3 hPa     | 3.4 m/s    | Fair (2.0)     | london   |
# +------------+------------+----------------+--------------+----------------+------------+----------------+----------+
# | 2025-04-01 | 8.7°C      | 61.4%          | 0.0 mm       | 1025.9 hPa     | 4.6 m/s    | Fair (2.0)     | london   |
# +------------+------------+----------------+--------------+----------------+------------+----------------+----------+
# | 2025-04-02 | 10.3°C     | 64.2%          | 0.0 mm       | 1022.5 hPa     | 5.3 m/s    | Fair (2.0)     | london   |
# +------------+------------+----------------+--------------+----------------+------------+----------------+----------+
# | 2025-04-03 | 11.8°C     | 66.9%          | 0.0 mm       | 1022.9 hPa     | 4.5 m/s    | Fair (2.0)     | london   |
# +------------+------------+----------------+--------------+----------------+------------+----------------+----------+
# | 2025-04-04 | 12.1°C     | 63.1%          | 0.0 mm       | 1022.4 hPa     | 4.7 m/s    | Moderate (3.0) | london   |
# +------------+------------+----------------+--------------+----------------+------------+----------------+----------+
# | 2025-04-05 | 8.0°C      | 71.6%          | 0.0 mm       | 1022.8 hPa     | 4.1 m/s    | N/A            | london   |
# +------------+------------+----------------+--------------+----------------+------------+----------------+----------+
# | 2025-03-31 | 16.8°C     | 82.0%          | 1.2 mm       | 1006.0 hPa     | 5.3 m/s    | Fair (2.0)     | new york |
# +------------+------------+----------------+--------------+----------------+------------+----------------+----------+
# | 2025-04-01 | 10.6°C     | 60.2%          | 26.5 mm      | 1008.2 hPa     | 6.6 m/s    | Fair (2.0)     | new york |
# +------------+------------+----------------+--------------+----------------+------------+----------------+----------+
# | 2025-04-02 | 6.2°C      | 41.1%          | 0.0 mm       | 1028.4 hPa     | 5.3 m/s    | Fair (2.0)     | new york |
# +------------+------------+----------------+--------------+----------------+------------+----------------+----------+
# | 2025-04-03 | 12.6°C     | 83.8%          | 0.7 mm       | 1021.2 hPa     | 6.2 m/s    | Fair (2.0)     | new york |
# +------------+------------+----------------+--------------+----------------+------------+----------------+----------+
# | 2025-04-04 | 15.6°C     | 75.5%          | 2.7 mm       | 1020.1 hPa     | 4.1 m/s    | Good (1.0)     | new york |
# +------------+------------+----------------+--------------+----------------+------------+----------------+----------+
# | 2025-04-05 | 12.0°C     | 60.6%          | 0.2 mm       | 1023.8 hPa     | 3.1 m/s    | N/A            | new york |
# +------------+------------+----------------+--------------+----------------+------------+----------------+----------+

# %% [markdown]
# <p align="center"><strong><em>STAY SAFE, STAY INFORMED, AND LET THE WEATHER BE YOUR GUIDE!</em></strong></p>
