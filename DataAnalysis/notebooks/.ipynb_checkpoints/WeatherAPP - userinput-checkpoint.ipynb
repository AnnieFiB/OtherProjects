# %% [markdown]
# # Real-Time Weather Dashboard with OpenWeather API

# %% [markdown]
# The project builds a Weather Dashboard using the OpenWeather API to fetch and display real-time weather details for one or two specified locations. Users can compare key weather data such as temperature, humidity, wind speed, and air conditions for these locations, with an option to save the data to a CSV file for future analysis.
#
# The dashboard aims to enhance skills in API integration, interactive interface, and data visualization (via Matplotlib).

# %% [markdown]
# ## Load Required Libraries

# %%
import sys
import os
#print(os.listdir("/kaggle/input/hlprfunct"))
# Get the absolute path of the 'scripts' directory
scripts_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'scripts'))
sys.path.append(scripts_path) # Add 'scripts' directory to sys.path
import weather

import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.simplefilter(action="ignore", category=DeprecationWarning)

# %% [markdown]
# ### Kaggle import

# %%
import importlib.util
import sys
import os

file_path = "/kaggle/input/hlprfunct/weatherk.py"
spec = importlib.util.spec_from_file_location("weatherk", file_path)
if spec:
    weatherk = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(weatherk)
else:
    print("Failed to load the module.")

import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.simplefilter(action="ignore", category=DeprecationWarning)

# %%
weather.main()
# Out:
# 1. View city weather
# 2. Compare cities
# Choose option (1/2):  2
# First city:
# Enter city and country (e.g., 'London UK'):  london england
# Second city:
# Enter city and country (e.g., 'London UK'):  ontario canada
# === Current Weather Comparison ===
# +-------------+---------------------+---------------------+
# | Attribute   | City 1              | City 2              |
# +=============+=====================+=====================+
# | City        | London, GB          | Ontario, US         |
# +-------------+---------------------+---------------------+
# | Temperature | 12.33°C             | 14.22°C             |
# +-------------+---------------------+---------------------+
# | Feels Like  | 11.47°C             | 13.92°C             |
# +-------------+---------------------+---------------------+
# | Pressure    | 1024 hPa            | 1017 hPa            |
# +-------------+---------------------+---------------------+
# | Humidity    | 71%                 | 85%                 |
# +-------------+---------------------+---------------------+
# | Weather     | clear sky           | haze                |
# +-------------+---------------------+---------------------+
# | Wind Speed  | 3.09 m/s            | 3.6 m/s             |
# +-------------+---------------------+---------------------+
# | Rain (1h)   | 0 mm                | 0 mm                |
# +-------------+---------------------+---------------------+
# | Sunrise     | 05:49:15            | 06:45:31            |
# +-------------+---------------------+---------------------+
# | Sunset      | 18:22:52            | 19:06:34            |
# +-------------+---------------------+---------------------+
# | Updated     | 2025-03-26 19:37:23 | 2025-03-26 12:37:58 |
# +-------------+---------------------+---------------------+
# | AQI         | Moderate (3)        | Poor (4)            |
# +-------------+---------------------+---------------------+
# === Combined Forecast Summary ===
# +------------+------------+----------------+--------------+----------------+------------+-----------------+---------+
# | date       | Avg Temp   | Avg Humidity   | Total Rain   | Avg Pressure   | Avg Wind   | AQI             | City    |
# +============+============+================+==============+================+============+=================+=========+
# | 2025-03-26 | 12.3°C     | 71.0%          | 0.0 mm       | 1024.0 hPa     | 2.4 m/s    | Moderate (3.0)  | london  |
# +------------+------------+----------------+--------------+----------------+------------+-----------------+---------+
# | 2025-03-27 | 12.4°C     | 69.2%          | 0.0 mm       | 1020.6 hPa     | 2.8 m/s    | Fair (2.0)      | london  |
# +------------+------------+----------------+--------------+----------------+------------+-----------------+---------+
# | 2025-03-28 | 9.3°C      | 72.5%          | 3.0 mm       | 1011.9 hPa     | 4.4 m/s    | Fair (2.0)      | london  |
# +------------+------------+----------------+--------------+----------------+------------+-----------------+---------+
# | 2025-03-29 | 8.0°C      | 62.4%          | 0.0 mm       | 1020.6 hPa     | 3.3 m/s    | Fair (2.0)      | london  |
# +------------+------------+----------------+--------------+----------------+------------+-----------------+---------+
# | 2025-03-30 | 10.1°C     | 66.5%          | 0.0 mm       | 1026.8 hPa     | 2.5 m/s    | Fair (2.0)      | london  |
# +------------+------------+----------------+--------------+----------------+------------+-----------------+---------+
# | 2025-03-31 | 12.4°C     | 69.1%          | 0.0 mm       | 1028.9 hPa     | 1.6 m/s    | N/A             | london  |
# +------------+------------+----------------+--------------+----------------+------------+-----------------+---------+
# | 2025-03-26 | 14.2°C     | 85.0%          | 0.0 mm       | 1017.0 hPa     | 3.7 m/s    | Very Poor (5.0) | ontario |
# +------------+------------+----------------+--------------+----------------+------------+-----------------+---------+
# | 2025-03-27 | 15.1°C     | 66.9%          | 0.0 mm       | 1017.1 hPa     | 2.3 m/s    | Moderate (3.0)  | ontario |
# +------------+------------+----------------+--------------+----------------+------------+-----------------+---------+
# | 2025-03-28 | 15.5°C     | 68.0%          | 0.1 mm       | 1014.8 hPa     | 2.7 m/s    | Fair (2.0)      | ontario |
# +------------+------------+----------------+--------------+----------------+------------+-----------------+---------+
# | 2025-03-29 | 15.0°C     | 62.8%          | 0.0 mm       | 1012.9 hPa     | 2.2 m/s    | Fair (2.0)      | ontario |
# +------------+------------+----------------+--------------+----------------+------------+-----------------+---------+
# | 2025-03-30 | 13.8°C     | 66.6%          | 0.6 mm       | 1014.9 hPa     | 3.4 m/s    | Fair (2.0)      | ontario |
# +------------+------------+----------------+--------------+----------------+------------+-----------------+---------+
# | 2025-03-31 | 13.5°C     | 68.9%          | 0.0 mm       | 1018.1 hPa     | 1.9 m/s    | N/A             | ontario |
# +------------+------------+----------------+--------------+----------------+------------+-----------------+---------+

# %% [markdown]
# <p align="center"><strong><em>STAY SAFE, STAY INFORMED, AND LET THE WEATHER BE YOUR GUIDE!</em></strong></p>
