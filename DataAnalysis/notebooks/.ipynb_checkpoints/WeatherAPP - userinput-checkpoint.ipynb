# %% [markdown]
# # Real-Time Weather Dashboard with OpenWeather API

# %% [markdown]
# The project builds a Weather Dashboard using the OpenWeather API to fetch and display real-time weather details for one or two specified locations. Users can compare key weather data such as temperature, humidity, wind speed, and air conditions for these locations, with an option to save the data to a CSV file for future analysis.
#
# The dashboard aims to enhance skills in API integration, interactive interface, and data visualization (via Matplotlib).

# %% [markdown]
# ## Load Required Libraries

# %%
import sys
import os

# Get the absolute path of the 'scripts' directory
scripts_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'scripts'))
sys.path.append(scripts_path) # Add 'scripts' directory to sys.path
import weather

import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.simplefilter(action="ignore", category=DeprecationWarning)

# %% [markdown]
# ### Kaggle import

# %%
import sys
import os
print(os.listdir("/kaggle/input/d/busayof/hlprfunct"))

# %%
import importlib.util

file_path = "/kaggle/input/d/busayof/hlprfunct/weatherk.py"
spec = importlib.util.spec_from_file_location("weatherk", file_path)
if spec:
    weatherk = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(weatherk)
else:
    print("Failed to load the module.")

import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.simplefilter(action="ignore", category=DeprecationWarning)

# %%
weather.main()
# Out:
# 1. View city weather
# 2. Compare cities
# Choose option (1/2):  1
# Enter city and country (e.g., 'London UK'):  london englan
# === Current Weather ===
# +-------------+---------------------+
# | City        | London, GB          |
# +-------------+---------------------+
# | Temperature | 11.53°C             |
# +-------------+---------------------+
# | Feels Like  | 10.64°C             |
# +-------------+---------------------+
# | Pressure    | 1024 hPa            |
# +-------------+---------------------+
# | Humidity    | 73%                 |
# +-------------+---------------------+
# | Weather     | clear sky           |
# +-------------+---------------------+
# | Wind Speed  | 2.57 m/s            |
# +-------------+---------------------+
# | Rain (1h)   | 0 mm                |
# +-------------+---------------------+
# | Sunrise     | 05:49:15            |
# +-------------+---------------------+
# | Sunset      | 18:22:52            |
# +-------------+---------------------+
# | Updated     | 2025-03-26 20:10:02 |
# +-------------+---------------------+
# | AQI         | Moderate (3)        |
# +-------------+---------------------+
# === Daily Forecast Summary ===
# +------------+------------+----------------+--------------+----------------+------------+----------------+
# | date       | Avg Temp   | Avg Humidity   | Total Rain   | Avg Pressure   | Avg Wind   | AQI            |
# +============+============+================+==============+================+============+================+
# | 2025-03-26 | 11.5°C     | 74.0%          | 0.0 mm       | 1024.0 hPa     | 2.4 m/s    | Moderate (3.0) |
# +------------+------------+----------------+--------------+----------------+------------+----------------+
# | 2025-03-27 | 12.3°C     | 69.6%          | 0.0 mm       | 1020.6 hPa     | 2.8 m/s    | Fair (2.0)     |
# +------------+------------+----------------+--------------+----------------+------------+----------------+
# | 2025-03-28 | 9.3°C      | 72.5%          | 3.0 mm       | 1011.9 hPa     | 4.4 m/s    | Fair (2.0)     |
# +------------+------------+----------------+--------------+----------------+------------+----------------+
# | 2025-03-29 | 8.0°C      | 62.4%          | 0.0 mm       | 1020.6 hPa     | 3.3 m/s    | Fair (2.0)     |
# +------------+------------+----------------+--------------+----------------+------------+----------------+
# | 2025-03-30 | 10.1°C     | 66.5%          | 0.0 mm       | 1026.8 hPa     | 2.5 m/s    | Fair (2.0)     |
# +------------+------------+----------------+--------------+----------------+------------+----------------+
# | 2025-03-31 | 12.4°C     | 69.1%          | 0.0 mm       | 1028.9 hPa     | 1.6 m/s    | N/A            |
# +------------+------------+----------------+--------------+----------------+------------+----------------+

# %% [markdown]
# <p align="center"><strong><em>STAY SAFE, STAY INFORMED, AND LET THE WEATHER BE YOUR GUIDE!</em></strong></p>
